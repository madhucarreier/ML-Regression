# %%
import pickle

# %%
##loaded the dynamic file and load the bulk of file data assign the value into load_model
load_model = pickle.load(open('finized_model_MultipleLinear.sav', 'rb')) 
# load_model.predict pass the numbers of input it will exexute we can able seethe in the result
result = load_model.predict([[23640.93,96189.63,148001.11,0,1]])
# Out:
# C:\Users\bkmad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[72072.64288041]])
